# %%
import requests
import xmltodict
import urllib, urllib.request
import mysql.connector
import time
from IPython.display import clear_output
import uuid
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## INIT

# %%
headers = {"x-api-key": "M7HSjQNeTfai6l7JUiDZB8XYc85BHnHt3R0NXSEd"}
# Establish database connection
cnx = mysql.connector.connect(user='david', password='daviddung1993',
                              host='127.0.0.1',
                              database='computervision')
cursor = cnx.cursor()

# %% [markdown]
# ## Fetching

# %%
# Semantic Scholar API
def semantic_paper_query(text):
    link = f"https://api.semanticscholar.org/graph/v1/paper/search?query={text}"
    response = requests.get(link, headers=headers).json()
    return response

def semantic_paper_details(paper_id):
    paper_link = f"https://api.semanticscholar.org/graph/v1/paper/{paper_id}?fields=url,year,referenceCount,citationCount,publicationTypes,journal,authors,title,references.url,references.title,references.year,references.referenceCount,references.citationCount,references.authors,references.journal,references.publicationTypes,authors.name,authors.affiliations,authors.paperCount,authors.hIndex,authors.aliases"
    response = requests.get(paper_link, headers=headers).json()
    return response

def semantic_author_details(author_id):
    author_link = f"https://api.semanticscholar.org/graph/v1/author/{author_id}?fields=affiliations,name,paperCount,hIndex,aliases"
    response = requests.get(author_link, headers=headers).json()
    return response

# %%
paper_link = f"https://api.semanticscholar.org/graph/v1/paper/025ef3fde2ee852ffabfa726eb6ea95a7d8de802?fields=externalIds,journal"
response = requests.get(paper_link, headers=headers).json()
response
# Out:
# {'paperId': '025ef3fde2ee852ffabfa726eb6ea95a7d8de802',
#  'externalIds': {'MAG': '1532415052', 'CorpusId': 22185830},
#  'journal': {'name': 'Proceedings of the 29th Chinese Control Conference',
#   'pages': '2792-2795'}}

# %%
semantic_paper_query("Outlier-Resistant Data Processing with L1-Norm")
# Out:
# {'total': 0, 'offset': 0, 'data': []}

# %% [markdown]
# # Fetch all the papers in the category cs.CV from 2000 - 2020

# %%
YEAR_START = 2015
YEAR_END = 2015
STEP_SIZE = 10
CATEGORY = "cs.CV"

# %%
def fetch_arxiv_entries(year_temp, current_index, STEP_SIZE):
    while True:
        try:
            arxiv_query = f'https://export.arxiv.org/api/query?search_query=cat:cs.CV+AND+submittedDate:[{year_temp}01010630+TO+{year_temp}12311645]&sortBy=submittedDate&start={current_index}&max_results={STEP_SIZE}'
            data = urllib.request.urlopen(arxiv_query)
            data_xml = data.read().decode('utf-8')
            data_dict = xmltodict.parse(data_xml)

            total_entries = int(data_dict['feed']['opensearch:totalResults']['#text'])
            print(f"{current_index}/{total_entries}")
            return data_dict['feed']['entry'], total_entries
        except KeyError:
            print("sleeping")
            time.sleep(3)

def store_authors(author_information, paperID):
    if not author_information:
        cursor.execute("INSERT INTO authoredBy VALUES (%s,%s)", [paperID, "0"])
        return
    for author in author_information:
        try:
            name = author["name"]
        except:
            print(author)
            raise KeyError
        affiliations = author["affiliations"]

        # Get full name
        if "." in name and author["aliases"]:
            for alias in author["aliases"]:
                if len(alias) > len(name):
                    name = alias
                if "." not in alias and len(alias.split(" ")[0]) > 2:
                    name = alias
                    break

        params = (author["authorId"], name, author["paperCount"], author["hIndex"])
        insert_author = "INSERT INTO Authors(AuthorID, Name, PaperCount, hIndex) VALUES (%s,%s,%s,%s)"
        insert_authoredBy = "INSERT INTO authoredBy VALUES (%s,%s)"

        try:
            cursor.execute(insert_author, params)
        except mysql.connector.IntegrityError as err:
            pass
        try:
            cursor.execute(insert_authoredBy, (paperID, author["authorId"]))
        except mysql.connector.IntegrityError as err:
            pass
        """
        if affiliations:
            for affiliation in affiliations:
                cursor.execute("SELECT * FROM Affiliations a WHERE a.Name=%s", [affiliation])
                entry = cursor.fetchone()
                if not entry:
                    cursor.execute("INSERT INTO Affiliations (Name) VALUES (%s)", [affiliation])
                    lastrowid = cursor.lastrowid
                else:
                    lastrowid = entry[0]
                try:
                    cursor.execute("INSERT INTO affiliatedTo VALUES (%s,%s)", [author["authorId"],lastrowid])
                except mysql.connector.IntegrityError as err:
                    pass

        else:
            try:
                cursor.execute("INSERT INTO affiliatedTo VALUES (%s,%s)", [author["authorId"],1])
            except mysql.connector.IntegrityError as err:
                pass
        """

def store_paper(archive_url, paper_response, isLeaf):
    isConference = False
    isJournalArticle = False
    isReview = False
    journal = ''
    if not paper_response['paperId']:
        cursor.execute("SELECT * FROM Papers p WHERE Title=%s", [paper_response["title"]])
        duplicate_paper = cursor.fetchall()
        if duplicate_paper:
            paper_response['paperId'] = duplicate_paper[0][0]
        else:
            paper_response['paperId'] = '11111' + uuid.uuid4().hex
    if paper_response["publicationTypes"]:
        if "JournalArticle" in paper_response["publicationTypes"]:
            isJournalArticle = True
        if "Conference" in paper_response["publicationTypes"]:
            isConference = True
        if "Review" in paper_response["publicationTypes"]:
            isReview = True
    if paper_response["journal"]:
        if "name" in paper_response["journal"]:
            journal = paper_response["journal"]["name"]
    params = [paper_response['paperId'], paper_response['title'], archive_url, paper_response['year'], CATEGORY, isReview, isConference, isJournalArticle,paper_response['referenceCount'], paper_response['citationCount'], journal, isLeaf, paper_response['url']]
    insert_paper = "INSERT INTO Papers VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    try:
        cursor.execute(insert_paper, params)
        return True
    except mysql.connector.IntegrityError as err:
        # If paper already exists check
        if isLeaf:
            return False

        check_if_leaf = "SELECT Leaf FROM Papers WHERE PaperID = %s"
        cursor.execute(check_if_leaf, [paper_response['paperId']])
        isLeafPaper = cursor.fetchone()[0]
        if isLeafPaper == isLeaf:
            return False

        update_leaf = "UPDATE Papers SET Leaf = %s WHERE PaperID = %s"
        cursor.execute(update_leaf, (isLeaf,paper_response['paperId']))
        return True

    except Exception as err:
        raise KeyError

def store_reference(paperId, referenced_by):
    try:
        insert_reference = "INSERT INTO referencedBy VALUES (%s,%s)"
        cursor.execute(insert_reference, (paperId, referenced_by))
    except mysql.connector.IntegrityError as err:
        pass

# %%
for i in range(YEAR_END - YEAR_START + 1):
    year_temp = YEAR_START + i
    print(year_temp)
    if year_temp == 2015:
        current_index = 1560
    else:
        current_index = 0
    var = 0
    while True:
        # Get title of all entries in a year from arxiv
        entries, total_entries = fetch_arxiv_entries(year_temp, current_index, STEP_SIZE)
        current_index += STEP_SIZE

        # Fetch information for papers from semantic scholar
        for entry in entries:
            var += 1
            print(var)
            archive_link = entry["id"]
            entry_title = entry["title"].replace("-", " ").replace("\n", "")
            response = semantic_paper_query(entry_title)

            if not response["total"]:
                continue
            else:
                while True:
                    try:
                        # Store papers' information in database
                        paperId = response["data"][0]["paperId"]
                        cursor.execute("select * from Papers p where p.PaperID = %s",[paperId])
                        exist_paper = cursor.fetchall()
                        if exist_paper and not exist_paper[0][-2]:
                            break
                        paper_response = semantic_paper_details(paperId)
                        if paper_response["referenceCount"] > 70 or paper_response["referenceCount"] == 0 or len(paper_response["authors"]) > 10:
                            break
                        success = store_paper(archive_link, paper_response, False)

                        if not success:
                            break

                        store_authors(paper_response['authors'], paperId)
                        # Store references' information in database
                        for reference in paper_response["references"]:
                            store_paper(None, reference, True)
                            store_reference(reference["paperId"], paperId)
                            if reference["authors"]:
                                for author in reference["authors"]:
                                    if not author["authorId"]:
                                        continue
                                    author_information = semantic_author_details(author["authorId"])
                                    store_authors([author_information], reference["paperId"])
                            else:
                                store_authors(None, reference["paperId"])
                        break
                    except KeyError:
                        continue
            cnx.commit()

        if current_index > total_entries:
            break
    clear_output(wait=True)

# %% [markdown]
# # Aggregate Results

# %%
universities = pd.read_csv("resources/world-universities.csv", names=['coutnry', 'university',"link"])["university"]

# %%
cursor.execute("select Name from Affiliations a")
all_affiliations = cursor.fetchall()

# %%
uni_count = {}
for uni in universities:
    uni_count[uni.lower()] = 0

# %%
for idx, uni in enumerate(uni_count):
    if idx % 250 == 0:
        print(idx)
    for affiliation in all_affiliations:
        if uni in affiliation[0].lower():
            uni_count[uni] += 1
# Out:
# 0
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# 2500
# 2750
# 3000
# 3250
# 3500
# 3750
# 4000
# 4250
# 4500
# 4750
# 5000
# 5250
# 5500
# 5750
# 6000
# 6250
# 6500
# 6750
# 7000
# 7250
# 7500
# 7750
# 8000
# 8250
# 8500
# 8750
# 9000
# 9250

# %%
non_zero_university = {k: v for k, v in uni_count.items() if v != 0}

# %%
sorted(non_zero_university.items(), key=lambda x:x[1], reverse=True)
# Out:
# [('university of technology', 670),
#  ('national university', 344),
#  ('university of science and technology', 315),
#  ('university of texas', 143),
#  ('university of illinois', 141),
#  ('massachusetts institute of technology', 137),
#  ('carnegie mellon university', 127),
#  ('university of hong kong', 120),
#  ('university of mary', 115),
#  ('institute of science and technology', 113),
#  ('stanford university', 111),
#  ('nanjing university', 106),
#  ('tsinghua university', 101),
#  ('university of toronto', 93),
#  ('university of california, san diego', 92),
#  ('city university', 91),
#  ('university of pennsylvania', 91),
#  ('university of washington', 91),
#  ('polytechnic university', 90),
#  ('york university', 87),
#  ('university of southern california', 85),
#  ('university of oxford', 83),
#  ('columbia university', 77),
#  ('johns hopkins university', 77),
#  ('zhejiang university', 76),
#  ('georgia institute of technology', 75),
#  ('national university of singapore', 71),
#  ('university of california, los angeles', 71),
#  ('peking university', 70),
#  ('university of california, berkeley', 70),
#  ('nanyang technological university', 67),
#  ('california institute of technology', 67),
#  ('new york university', 67),
#  ('purdue university', 65),
#  ('technische universität münchen', 62),
#  ('yale university', 62),
#  ('university of london', 60),
#  ('duke university', 59),
#  ('wuhan university', 57),
#  ('university of waterloo', 56),
#  ('university of cambridge', 56),
#  ('chinese university of hong kong', 56),
#  ('university of british columbia', 55),
#  ('cornell university', 55),
#  ('ecole polytechnique', 54),
#  ('princeton university', 52),
#  ('boston university', 51),
#  ('harvard university', 50),
#  ('university of florida', 50),
#  ('mcgill university', 49),
#  ('huazhong university of science and technology', 49),
#  ('seoul national university', 49),
#  ('western university', 47),
#  ('university of edinburgh', 47),
#  ('national taiwan university', 47),
#  ('australian national university', 45),
#  ('imperial college london', 45),
#  ('institute of information technology', 45),
#  ('hong kong polytechnic university', 44),
#  ('university of iowa', 44),
#  ('beijing institute of technology', 43),
#  ('harbin institute of technology', 42),
#  ('national university of defense technology', 42),
#  ('pennsylvania state university', 42),
#  ('university of utah', 42),
#  ('university of sydney', 41),
#  ('monash university', 40),
#  ('university of surrey', 40),
#  ('university of rochester', 40),
#  ('university of melbourne', 39),
#  ('university of applied sciences', 39),
#  ('rensselaer polytechnic institute', 39),
#  ('university of pittsburgh', 38),
#  ('university of queensland', 37),
#  ('university of manchester', 37),
#  ('university of athens', 37),
#  ('university of arizona', 37),
#  ('university of central florida', 37),
#  ('simon fraser university', 36),
#  ('shanghai jiaotong university', 36),
#  ('indian institute of science', 36),
#  ('university of amsterdam', 36),
#  ('arizona state university', 36),
#  ('ohio state university', 36),
#  ('university of chicago', 36),
#  ('concordia university', 35),
#  ('university of alberta', 35),
#  ('university of western ontario', 35),
#  ('osaka university', 35),
#  ('yonsei university', 35),
#  ('michigan state university', 35),
#  ('northwestern university', 35),
#  ('tianjin university', 34),
#  ('brown university', 34),
#  ('katholieke universiteit leuven', 33),
#  ('universidad nacional', 33),
#  ('university of nottingham', 33),
#  ('tel aviv university', 32),
#  ('north carolina state university', 32),
#  ('university of illinois at urbana-champaign', 32),
#  ('university of bristol', 31),
#  ('delft university of technology', 31),
#  ('university of texas at austin', 31),
#  ('queensland university of technology', 30),
#  ('university of new south wales', 30),
#  ('city university of hong kong', 30),
#  ('university of california, santa barbara', 30),
#  ('université de montréal', 29),
#  ('fudan university', 29),
#  ('south china university', 29),
#  ('south china university of technology', 29),
#  ('university of electronic science and technology of china', 29),
#  ('weizmann institute of science', 29),
#  ('rice university', 29),
#  ('university of houston', 29),
#  ('ie university', 28),
#  ('university of sheffield', 28),
#  ('hong kong university of science and technology', 28),
#  ('kyoto university', 28),
#  ('international university', 28),
#  ('eastern university', 27),
#  ('sichuan university', 27),
#  ('university of south florida', 27),
#  ('vanderbilt university', 27),
#  ('university of western australia', 26),
#  ('chongqing university', 26),
#  ('northeastern university', 26),
#  ('university of oulu', 26),
#  ('hebrew university of jerusalem', 26),
#  ('university of bologna', 26),
#  ('texas a&m university', 26),
#  ('university of california, davis', 26),
#  ('technical university of denmark', 25),
#  ('linköping university', 25),
#  ('dartmouth college', 25),
#  ('université catholique de louvain', 24),
#  ('hebei university', 24),
#  ('xiamen university', 24),
#  ('lund university', 24),
#  ('university of south carolina', 24),
#  ('university of adelaide', 23),
#  ('mcmaster university', 23),
#  ('dalian university', 23),
#  ('nanjing university of science and technology', 23),
#  ('shanghai university', 23),
#  ('university of helsinki', 23),
#  ('university of southampton', 23),
#  ('beijing university of posts and telecommunications', 22),
#  ('dalian university of technology', 22),
#  ('shandong university', 22),
#  ('university of leeds', 22),
#  ('korea university', 22),
#  ('university of auckland', 22),
#  ('george mason university', 22),
#  ('university of delaware', 22),
#  ('university of kentucky', 22),
#  ('university of ottawa', 21),
#  ('indian statistical institute', 21),
#  ('tokyo institute of technology', 21),
#  ('southeast university', 20),
#  ("king's college", 20),
#  ('kyungpook national university', 20),
#  ('national cheng kung university', 20),
#  ('national chiao tung university', 20),
#  ('rochester institute of technology', 20),
#  ('university of california, irvine', 20),
#  ('university of miami', 20),
#  ("queen's university", 19),
#  ('university of calgary', 19),
#  ('university of science and technology of china', 19),
#  ('helsinki university of technology', 19),
#  ('university of florence', 19),
#  ('case western reserve university', 19),
#  ('florida state university', 19),
#  ('mississippi state university', 19),
#  ('new jersey institute of technology', 19),
#  ('university of california, san francisco', 19),
#  ('university of virginia', 19),
#  ('university of wollongong', 18),
#  ('open university', 18),
#  ('kyushu university', 18),
#  ('multimedia university', 18),
#  ('eindhoven university of technology', 18),
#  ('leiden university', 18),
#  ('universidade do porto', 18),
#  ('bilkent university', 18),
#  ('national central university', 18),
#  ('colorado state university', 18),
#  ('drexel university', 18),
#  ('university of california, santa cruz', 18),
#  ('university of louisville', 18),
#  ('utah state university', 18),
#  ('university of newcastle', 17),
#  ('university of reading', 17),
#  ('university of crete', 17),
#  ('anna university', 17),
#  ('university of tehran', 17),
#  ('university of genoa', 17),
#  ('university of electro-communications', 17),
#  ('pohang university of science and technology', 17),
#  ('university of east', 17),
#  ('chalmers university of technology', 17),
#  ('university of ljubljana', 17),
#  ('brigham young university', 17),
#  ('temple university', 17),
#  ('university of north carolina at chapel hill', 17),
#  ('university of liverpool', 16),
#  ('university of warwick', 16),
#  ('university of patras', 16),
#  ('university of zagreb', 16),
#  ('ben-gurion university of the negev', 16),
#  ('indian institute of technology, kharagpur', 16),
#  ('university of trento', 16),
#  ('university of groningen', 16),
#  ('school of management', 16),
#  ('tufts university', 16),
#  ('university of kansas', 16),
#  ('american university', 15),
#  ('nanjing university of aeronautics and astronautics', 15),
#  ("xi'an jiaotong university", 15),
#  ('freie universität berlin', 15),
#  ('university of birmingham', 15),
#  ('jadavpur university', 15),
#  ('waseda university', 15),
#  ('hanyang university', 15),
#  ('wayne state university', 15),
#  ('vrije universiteit brussel', 14),
#  ('universidade de são paulo', 14),
#  ('university of victoria', 14),
#  ('swiss federal institute of technology, lausanne', 14),
#  ('beijing normal university', 14),
#  ('hefei university of technology', 14),
#  ('universidad de granada', 14),
#  ('tampere university of technology', 14),
#  ('heriot-watt university', 14),
#  ('kingston university', 14),
#  ('university of essex', 14),
#  ('university of sussex', 14),
#  ('keio university', 14),
#  ('kyushu institute of technology', 14),
#  ('tokyo university', 14),
#  ('universiti teknologi malaysia', 14),
#  ('university of connecticut', 14),
#  ('university of new mexico', 14),
#  ('deakin university', 13),
#  ('griffith university', 13),
#  ('victoria university', 13),
#  ('anhui university', 13),
#  ('jilin university', 13),
#  ('southwest jiaotong university', 13),
#  ('universität stuttgart', 13),
#  ('cairo university', 13),
#  ('universidad autónoma de madrid', 13),
#  ('universidad politécnica de madrid', 13),
#  ('university of wales', 13),
#  ('university of ioannina', 13),
#  ('hong kong baptist university', 13),
#  ('university college dublin', 13),
#  ('amirkabir university of technology', 13),
#  ('hokkaido university', 13),
#  ('tohoku university', 13),
#  ('university of twente', 13),
#  ('university of oslo', 13),
#  ('king saud university', 13),
#  ('istanbul technical university', 13),
#  ('national chung cheng university', 13),
#  ('national taiwan university of science and technology', 13),
#  ('syracuse university', 13),
#  ('university of texas at arlington', 13),
#  ('west virginia university', 13),
#  ('dalhousie university', 12),
#  ('university of windsor', 12),
#  ('lanzhou university', 12),
#  ('nanjing university of posts and telecommunications', 12),
#  ('shenzhen university', 12),
#  ('universität hannover', 12),
#  ('universitat pompeu fabra', 12),
#  ('university of glasgow', 12),
#  ('university of ulster', 12),
#  ('national technical university of athens', 12),
#  ('sharif university of technology', 12),
#  ('university of canterbury', 12),
#  ('moscow state university', 12),
#  ('middle east technical university', 12),
#  ('baylor college of medicine', 12),
#  ('florida international university', 12),
#  ('illinois institute of technology', 12),
#  ('oregon state university', 12),
#  ('the johns hopkins university', 12),
#  ('university of geneva', 11),
#  ('harbin engineering university', 11),
#  ('hunan university', 11),
#  ('brno university of technology', 11),
#  ('alexandria university', 11),
#  ('université de toulouse', 11),
#  ('university of bradford', 11),
#  ('university of dundee', 11),
#  ('university of east anglia', 11),
#  ('national university of ireland', 11),
#  ('university of pisa', 11),
#  ('nagoya institute of technology', 11),
#  ('utrecht university', 11),
#  ('university of bergen', 11),
#  ('uppsala university', 11),
#  ('national taipei university', 11),
#  ('atlantic university', 11),
#  ('florida atlantic university', 11),
#  ('texas tech university', 11),
#  ('university of california, riverside', 11),
#  ('university of notre dame', 11),
#  ('university of saskatchewan', 10),
#  ('universidad de chile', 10),
#  ('china agricultural university', 10),
#  ('ocean university of china', 10),
#  ('technische universität berlin', 10),
#  ('ain shams university', 10),
#  ('universidad de las palmas de gran canaria', 10),
#  ('universidad de zaragoza', 10),
#  ('universitat de barcelona', 10),
#  ('university of jyväskylä', 10),
#  ('cardiff university', 10),
#  ('bar-ilan university', 10),
#  ('university of haifa', 10),
#  ('indian institute of information technology', 10),
#  ('university of trieste', 10),
#  ('kobe university', 10),
#  ('okayama university', 10),
#  ('tokyo university of agriculture', 10),
#  ('toyota technological institute', 10),
#  ('ajou university', 10),
#  ('inha university', 10),
#  ('universiti teknologi mara', 10),
#  ('massey university', 10),
#  ('air force institute of technology', 10),
#  ('emory university', 10),
#  ('george washington university', 10),
#  ('kansas state university', 10),
#  ('stevens institute of technology', 10),
#  ('university of cincinnati', 10),
#  ('university of maryland baltimore county', 10),
#  ('university of texas at dallas', 10),
#  ('university of cape town', 10),
#  ('swinburne university of technology', 9),
#  ('university of technology sydney', 9),
#  ('metropolitan university', 9),
#  ('universidade federal de minas gerais', 9),
#  ('universidade federal de pernambuco', 9),
#  ('université laval', 9),
#  ('university of new brunswick', 9),
#  ('swiss federal institute of technology, zurich', 9),
#  ('central south university', 9),
#  ('north china electric power university', 9),
#  ('tongji university', 9),
#  ('aalborg university', 9),
#  ('university of tampere', 9),
#  ('university of bath', 9),
#  ('university of strathclyde', 9),
#  ('aristotle university of thessaloniki', 9),
#  ('technical university of crete', 9),
#  ('chiba university', 9),
#  ('chonnam national university', 9),
#  ('tilburg university', 9),
#  ('wageningen university', 9),
#  ('norwegian university of science and technology', 9),
#  ('university of otago', 9),
#  ('oklahoma state university', 9),
#  ('university of oregon', 9),
#  ('university of rhode island', 9),
#  ('worcester polytechnic institute', 9),
#  ('wright state university', 9),
#  ('university of pretoria', 9),
#  ('macquarie university', 8),
#  ('université libre de bruxelles', 8),
#  ('university of zürich', 8),
#  ('communication university of china', 8),
#  ('east china normal university', 8),
#  ('fuzhou university', 8),
#  ('nanjing normal university', 8),
#  ('northeast normal university', 8),
#  ('wuhan university of technology', 8),
#  ('aarhus university', 8),
#  ('assiut university', 8),
#  ('universidad rey juan carlos', 8),
#  ('ecole normale supérieure de cachan', 8),
#  ('université de poitiers', 8),
#  ('aston university', 8),
#  ('university of aberdeen', 8),
#  ('dublin city university', 8),
#  ('technion - israel institute of technology', 8),
#  ('chosun university', 8),
#  ('chung-ang university', 8),
#  ('universiti putra malaysia', 8),
#  ('bogazici university', 8),
#  ('chung yuan christian university', 8),
#  ('i-shou university', 8),
#  ('national taiwan normal university', 8),
#  ('soochow university', 8),
#  ('tamkang university', 8),
#  ('dakota state university', 8),
#  ('ici university', 8),
#  ('rutgers, the state university of new jersey', 8),
#  ('state university of new york at buffalo', 8),
#  ('university of illinois at chicago', 8),
#  ('university of medicine and dentistry of new jersey', 8),
#  ('university of texas at san antonio', 8),
#  ('wake forest university', 8),
#  ('universidad de buenos aires', 7),
#  ('la trobe university', 7),
#  ('universidade federal do rio de janeiro', 7),
#  ('carleton university', 7),
#  ('memorial university of newfoundland', 7),
#  ('université de sherbrooke', 7),
#  ('university of guelph', 7),
#  ('university of manitoba', 7),
#  ('university of basel', 7),
#  ('guangdong university of technology', 7),
#  ('hubei university', 7),
#  ('nankai university', 7),
#  ('ningbo university', 7),
#  ('university of science and technology beijing', 7),
#  ('masaryk university', 7),
#  ('university of ostrava', 7),
#  ('technische universität dresden', 7),
#  ('universidad politécnica de valencia', 7),
#  ('lappeenranta university of technology', 7),
#  ('university of turku', 7),
#  ('ecole centrale de lyon', 7),
#  ('oxford brookes university', 7),
#  ('university of exeter', 7),
#  ('university of milan', 7),
#  ('university of verona', 7),
#  ('nagoya university', 7),
#  ('ritsumeikan university', 7),
#  ('tokyo denki university', 7),
#  ('tokyo university of agriculture and technology', 7),
#  ('university of waikato', 7),
#  ('university of education', 7),
#  ('university of bucharest', 7),
#  ('university of belgrade', 7),
#  ('national taipei university of technology', 7),
#  ('clemson university', 7),
#  ('montana state university', 7),
#  ('national defense university', 7),
#  ('northwest university', 7),
#  ('san diego state university', 7),
#  ('the scripps research institute', 7),
#  ('university of mississippi', 7),
#  ('university of north texas', 7),
#  ('central queensland university', 6),
#  ('curtin university of technology', 6),
#  ('university of south australia', 6),
#  ('university of regina', 6),
#  ('beijing university of aeronautics and astronautics', 6),
#  ('shanghai maritime university', 6),
#  ('tianjin university of technology', 6),
#  ('silesian university', 6),
#  ('ruhr-universität bochum', 6),
#  ('technische universität darmstadt', 6),
#  ('universität dortmund', 6),
#  ('copenhagen university', 6),
#  ('nile university', 6),
#  ('universidad carlos iii de madrid', 6),
#  ('université de technologie de compiègne', 6),
#  ('loughborough university', 6),
#  ('university of st. andrews', 6),
#  ('university of york', 6),
#  ('national university of ireland, galway', 6),
#  ('indian institute of technology, kanpur', 6),
#  ('psg college of technology', 6),
#  ('art university', 6),
#  ('isfahan university', 6),
#  ('university of iceland', 6),
#  ('university of pavia', 6),
#  ('university of perugia', 6),
#  ('hiroshima city university', 6),
#  ('mie university', 6),
#  ('tottori university', 6),
#  ('university of aizu', 6),
#  ('chonbuk national university', 6),
#  ('dongguk university', 6),
#  ('konkuk university', 6),
#  ('kwangwoon university', 6),
#  ('university of macau', 6),
#  ('örebro university', 6),
#  ('anadolu university', 6),
#  ('sabanci university', 6),
#  ('national yunlin university of science and technology', 6),
#  ('yuan ze university', 6),
#  ('boston college', 6),
#  ('brandeis university', 6),
#  ('mount sinai school of medicine', 6),
#  ('naval postgraduate school', 6),
#  ('new mexico state university', 6),
#  ('old dominion university', 6),
#  ('southern methodist university', 6),
#  ('university of denver', 6),
#  ('university of georgia', 6),
#  ('university of memphis', 6),
#  ('university of oklahoma', 6),
#  ('university of toledo', 6),
#  ('washington university in st. louis', 6),
#  ('university of kwazulu-natal', 6),
#  ('universidad nacional de córdoba', 5),
#  ('charles sturt university', 5),
#  ('university of canberra', 5),
#  ('hasselt university', 5),
#  ('university of lausanne', 5),
#  ('chengdu university', 5),
#  ('liaoning normal university', 5),
#  ('qingdao university', 5),
#  ('renmin university of china', 5),
#  ('zhejiang university of technology', 5),
#  ('universidad industrial de santander', 5),
#  ('university of cyprus', 5),
#  ('universität bielefeld', 5),
#  ('universität des saarlandes', 5),
#  ('universität kaiserslautern', 5),
#  ('menoufia university', 5),
#  ('universidad de sevilla', 5),
#  ('université de reims champagne-ardenne', 5),
#  ('birkbeck college, university of london', 5),
#  ('bournemouth university', 5),
#  ('university of lincoln', 5),
#  ('university of paisley', 5),
#  ('university of western macedonia', 5),
#  ('university of szeged', 5),
#  ('banaras hindu university', 5),
#  ('cochin university of science and technology', 5),
#  ('jaypee institute of information technology', 5),
#  ('university of calcutta', 5),
#  ('university of hyderabad', 5),
#  ('ferdowsi university of mashhad', 5),
#  ('shiraz university', 5),
#  ('tarbiat modares university', 5),
#  ('university of bari', 5),
#  ('university of modena', 5),
#  ('university of padua', 5),
#  ('university of siena', 5),
#  ('hosei university', 5),
#  ('niigata university', 5),
#  ('shinshu university', 5),
#  ('tokai university', 5),
#  ('toyohashi university of technology', 5),
#  ('yamaguchi university', 5),
#  ('korea advanced institute of science & technology', 5),
#  ('pusan national university', 5),
#  ('universiti kebangsaan malaysia', 5),
#  ('erasmus university rotterdam', 5),
#  ('swedish university of agricultural sciences', 5),
#  ('kasetsart university', 5),
#  ('osmangazi university', 5),
#  ('chang gung university', 5),
#  ('national taiwan ocean university', 5),
#  ('clarkson university', 5),
#  ('colorado school of mines', 5),
#  ('georgia state university', 5),
#  ('kent state university', 5),
#  ('michigan technological university', 5),
#  ('northern illinois university', 5),
#  ('ohio university', 5),
#  ('pace university', 5),
#  ('san francisco state university', 5),
#  ('south dakota state university', 5),
#  ('university of colorado at boulder', 5),
#  ('university of idaho', 5),
#  ('university of north carolina at charlotte', 5),
#  ('university of vermont', 5),
#  ('washington state university', 5),
#  ('university of sharjah', 4),
#  ('universität innsbruck', 4),
#  ('universität klagenfurt', 4),
#  ('edith cowan university', 4),
#  ('university of ballarat', 4),
#  ('university of tasmania', 4),
#  ('bangladesh university', 4),
#  ('université de liège', 4),
#  ('universidade federal do rio grande do sul', 4),
#  ('lakehead university', 4),
#  ('trent university', 4),
#  ('university of fribourg', 4),
#  ('central university of finance and economics', 4),
#  ('east china university of science and technology', 4),
#  ('guangxi normal university', 4),
#  ('hebei university of science and technology', 4),
#  ('hebei university of technology', 4),
#  ('inner mongolia university', 4),
#  ('nanjing medical university', 4),
#  ('northeast agricultural university', 4),
#  ('south china agricultural university', 4),
#  ('southern yangtze university', 4),
#  ('southwest university', 4),
#  ('university of petroleum (east china)', 4),
#  ('yangtze university', 4),
#  ('yangzhou university', 4),
#  ('eastern mediterranean university', 4),
#  ('ludwig-maximilians-universität münchen', 4),
#  ('universität bremen', 4),
#  ('universität hamburg', 4),
#  ('universität leipzig', 4),
#  ('universität trier', 4),
#  ('american university in cairo', 4),
#  ('helwan university', 4),
#  ('mansoura university', 4),
#  ('universidad complutense de madrid', 4),
#  ('universidad de la rioja', 4),
#  ('universidad de málaga', 4),
#  ('universidad de oviedo', 4),
#  ('universidad de valladolid', 4),
#  ('universidad de vigo', 4),
#  ('universidad nacional de educación a distancia', 4),
#  ('universidad politécnica de cartagena', 4),
#  ('ecole normale supérieure de lyon', 4),
#  ('université de bretagne sud', 4),
#  ('université de technologie de troyes', 4),
#  ('coventry university', 4),
#  ('liverpool john moores university', 4),
#  ('sheffield hallam university', 4),
#  ('university of derby', 4),
#  ('university of durham', 4),
#  ('university of plymouth', 4),
#  ('university college cork', 4),
#  ('open university of israel', 4),
#  ('birla institute of technology and science', 4),
#  ('indian institute of technology, bombay', 4),
#  ('indian institute of technology, guwahati', 4),
#  ('kuvempu university', 4),
#  ('university of delhi', 4),
#  ('isfahan university of technology', 4),
#  ('shahrood university of technology', 4),
#  ('university of cagliari', 4),
#  ('university of calabria', 4),
#  ('university of catania', 4),
#  ('university of ferrara', 4),
#  ('university of naples federico ii', 4),
#  ('university of salerno', 4),
#  ('new york institute of technology', 4),
#  ('university of jordan', 4),
#  ('chukyo university', 4),
#  ('gunma university', 4),
#  ('hiroshima university', 4),
#  ('japan advanced institute of science and technology', 4),
#  ('kanazawa university', 4),
#  ('kinki university', 4),
#  ('meiji university', 4),
#  ('nagaoka university of technology', 4),
#  ('science university of tokyo', 4),
#  ('shizuoka university', 4),
#  ('utsunomiya university', 4),
#  ('chungbuk national university', 4),
#  ('hongik university', 4),
#  ('myongji university', 4),
#  ('sejong university', 4),
#  ('sogang university', 4),
#  ('university of montenegro', 4),
#  ('universiti malaysia perlis', 4),
#  ('universiti teknologi petronas', 4),
#  ('paul university', 4),
#  ('university of maastricht', 4),
#  ('victoria university of wellington', 4),
#  ('xavier university', 4),
#  ('comsats institute of information technology', 4),
#  ('national university of science and technology', 4),
#  ('agh university of science and technology', 4),
#  ('universidade de coimbra', 4),
#  ('universidade de lisboa', 4),
#  ('technical university of cluj-napoca', 4),
#  ('blekinge institute of technology', 4),
#  ('singapore management university', 4),
#  ('chiang mai university', 4),
#  ('hacettepe university', 4),
#  ('national chengchi university', 4),
#  ('national chi nan university', 4),
#  ('national chung hsing university, taichung', 4),
#  ('national kaohsiung first university of science and technology', 4),
#  ('national university of kaohsiung', 4),
#  ('providence university', 4),
#  ('bowling green state university', 4),
#  ('central michigan university', 4),
#  ('florida institute of technology', 4),
#  ('marquette university', 4),
#  ('medical college of wisconsin', 4),
#  ('medical university of south carolina', 4),
#  ('morgan state university', 4),
#  ('portland state university', 4),
#  ('queens college', 4),
#  ('smith college', 4),
#  ('tennessee state university', 4),
#  ('the rockefeller university', 4),
#  ('thomas jefferson university', 4),
#  ('university of bridgeport', 4),
#  ('university of california, merced', 4),
#  ('university of colorado at denver', 4),
#  ('university of north dakota', 4),
#  ('university of tulsa', 4),
#  ('virginia commonwealth university', 4),
#  ('western washington university', 4),
#  ('khalifa university', 3),
#  ('universidad nacional del sur', 3),
#  ('technische universität wien', 3),
#  ('bangladesh university of engineering and technology', 3),
#  ('universidade estadual de campinas', 3),
#  ('universidade federal de alagoas', 3),
#  ('universidade federal de são carlos', 3),
#  ('universidade federal do ceará', 3),
#  ('universidade federal do paraná', 3),
#  ('acadia university', 3),
#  ('university of ontario institute of technology', 3),
#  ('universidad de los andes', 3),
#  ('beijing university of chemical technology', 3),
#  ('central china normal university', 3),
#  ('changchun university of technology', 3),
#  ('guangdong university of foreign studies', 3),
#  ('guizhou university', 3),
#  ('jinan university', 3),
#  ('liaoning university', 3),
#  ('nanchang university', 3),
#  ('nanjing agricultural university', 3),
#  ('qingdao university of science and technology', 3),
#  ('shandong normal university', 3),
#  ('shandong university of science and technology', 3),
#  ('shanghai university of finance and economics', 3),
#  ('shenyang university', 3),
#  ('south china normal university', 3),
#  ('tianjin medical university', 3),
#  ('tianjin normal university', 3),
#  ('wenzhou university', 3),
#  ('yunnan university', 3),
#  ('zhejiang gongshang university', 3),
#  ('zhejiang normal university', 3),
#  ('pontificia universidad javeriana', 3),
#  ('universidad de antioquia', 3),
#  ('universidad nacional de colombia', 3),
#  ('cyprus university of technology', 3),
#  ('albert-ludwigs-universität freiburg', 3),
#  ('jacobs university bremen', 3),
#  ('technische universität ilmenau', 3),
#  ('universität augsburg', 3),
#  ('universität konstanz', 3),
#  ('universität regensburg', 3),
#  ('westfälische wilhelms-universität münster', 3),
#  ('university of southern denmark', 3),
#  ('minia university', 3),
#  ('universidad de alicante', 3),
#  ('universidad de la laguna', 3),
#  ('universidad del país vasco', 3),
#  ('universidad de murcia', 3),
#  ('universidad de valencia', 3),
#  ('universidad pública de navarra', 3),
#  ('universitat de les illes balears', 3),
#  ('addis ababa university', 3),
#  ('university of joensuu', 3),
#  ('university of kuopio', 3),
#  ('institut national des sciences appliquées de lyon', 3),
#  ('institut national des télécommunications', 3),
#  ('université bordeaux i', 3),
#  ('université de bourgogne', 3),
#  ('université de nantes', 3),
#  ('université jean monnet', 3),
#  ('goldsmiths college, university of london', 3),
#  ('middlesex university', 3),
#  ('staffordshire university', 3),
#  ('university of central lancashire', 3),
#  ('university of huddersfield', 3),
#  ('university of lancaster', 3),
#  ('university of leicester', 3),
#  ('university of salford', 3),
#  ('university of sunderland', 3),
#  ('university of wales, aberystwyth', 3),
#  ('university of westminster', 3),
#  ('university of piraeus', 3),
#  ('national university of ireland, maynooth', 3),
#  ('college of management', 3),
#  ('bangalore university', 3),
#  ('gulbarga university', 3),
#  ('indian institute of technology, madras', 3),
#  ('indian institute of technology, roorkee', 3),
#  ('jawaharlal nehru technological university', 3),
#  ('kannur university', 3),
#  ('panjab university', 3),
#  ('periyar university', 3),
#  ('thiagarajar college of engineering', 3),
#  ('university of burdwan', 3),
#  ('university of mysore', 3),
#  ('islamic azad university, qazvin', 3),
#  ('abdus salam international centre for theoretical physics', 3),
#  ('university of messina', 3),
#  ('university of sassari', 3),
#  ('aichi institute of technology', 3),
#  ('aichi prefectural university', 3),
#  ('chubu university', 3),
#  ('chuo university', 3),
#  ('iwate medical university', 3),
#  ('iwate university', 3),
#  ('kagawa university', 3),
#  ('meijo university', 3),
#  ('oita university', 3),
#  ('seikei university', 3),
#  ('shimane university', 3),
#  ('yamagata university', 3),
#  ('chungnam national university', 3),
#  ('dongseo university', 3),
#  ('hallym university', 3),
#  ('keimyung university', 3),
#  ('kookmin university', 3),
#  ('soongsil university', 3),
#  ('sung kyun kwan university', 3),
#  ('american university of beirut', 3),
#  ('lebanese university', 3),
#  ('university of peradeniya', 3),
#  ('university of malta', 3),
#  ('instituto politécnico nacional', 3),
#  ('universidad autónoma metropolitana', 3),
#  ('international islamic university', 3),
#  ('universiti sains malaysia', 3),
#  ('universiti teknikal malaysia melaka', 3),
#  ('norwegian university of life sciences', 3),
#  ('university of tromsø', 3),
#  ('pontificia universidad católica del perú', 3),
#  ('mohammad ali jinnah university', 3),
#  ('technical university of lodz', 3),
#  ('university of lodz', 3),
#  ('university of silesia', 3),
#  ('university of warsaw', 3),
#  ('universidade de aveiro', 3),
#  ('universidade nova de lisboa', 3),
#  ('university of iasi', 3),
#  ('university of novi sad', 3),
#  ('higher school of economics', 3),
#  ('king abdullah university of science and technology ', 3),
#  ("king mongkut's university of technology thonburi", 3),
#  ('mahanakorn university of technology', 3),
#  ('mahidol university', 3),
#  ('erciyes university', 3),
#  ('koc university', 3),
#  ('sakarya university', 3),
#  ('yildiz technical university', 3),
#  ('da-yeh university', 3),
#  ('lunghwa university of science and technology', 3),
#  ('ming chuan university', 3),
#  ('national changhua university of education', 3),
#  ('national dong hwa university', 3),
#  ('national sun yat-sen university', 3),
#  ('national united university', 3),
#  ('auburn university', 3),
#  ('bucknell university', 3),
#  ('cleveland state university', 3),
#  ('college of william and mary', 3),
#  ('depaul university', 3),
#  ('duquesne university', 3),
#  ('fred hutchinson cancer research center', 3),
#  ('georgetown university', 3),
#  ('grinnell college', 3),
#  ('james madison university', 3),
#  ('loma linda university', 3),
#  ('louisiana tech university', 3),
#  ('middlebury college', 3),
#  ('missouri university of science and technology', 3),
#  ('new york medical college', 3),
#  ('north dakota state university', 3),
#  ('oakland university', 3),
#  ('sam houston state university', 3),
#  ('san jose state university', 3),
#  ('santa clara university', 3),
#  ('standford university', 3),
#  ('state university of new york at stony brook', 3),
#  ('tennessee technological university', 3),
#  ('unity college', 3),
#  ('university of akron', 3),
#  ('university of dayton', 3),
#  ('university of new orleans', 3),
#  ('university of rio grande', 3),
#  ('university of texas at el paso', 3),
#  ('university of west florida', 3),
#  ('university of wyoming', 3),
#  ('universidad de la república', 3),
#  ('university of stellenbosch', 3),
#  ('american university of sharjah', 2),
#  ('united arab emirates university', 2),
#  ('zayed university', 2),
#  ('universidad nacional de la plata', 2),
#  ('universidad nacional de río cuarto', 2),
#  ('medizinische universität innsbruck', 2),
#  ('wirtschaftsuniversität wien', 2),
#  ('australian defence force academy', 2),
#  ('murdoch university', 2),
#  ('royal melbourne institute of technology', 2),
#  ('university of new england', 2),
#  ('university of southern queensland', 2),
#  ('brac university', 2),
#  ('chittagong university of engineering and technology', 2),
#  ('khulna university', 2),
#  ('khulna university of engineering and technology', 2),
#  ('queens university', 2),
#  ('university of dhaka', 2),
#  ('university of rajshahi', 2),
#  ('royal military academy', 2),
#  ('universiteit antwerpen', 2),
#  ('universiteit gent', 2),
#  ('universidade estadual do norte fluminense', 2),
#  ('universidade federal de lavras', 2),
#  ('universidade federal de mato grosso', 2),
#  ('universidade federal de mato grosso do sul', 2),
#  ('universidade federal de ouro preto', 2),
#  ('universidade federal de santa maria', 2),
#  ('universidade federal do rio grande do norte', 2),
#  ('st. francis xavier university', 2),
#  ('université du québec à montréal', 2),
#  ('university of lethbridge', 2),
#  ('university of moncton', 2),
#  ('university of new brunswick, saint john', 2),
#  ('university of winnipeg', 2),
#  ('universidad de los lagos', 2),
#  ('capital normal university', 2),
#  ('central university for nationalities', 2),
#  ('chengdu university of technology', 2),
#  ('civil aviation university of china', 2),
#  ('east china jiao tong university', 2),
#  ('fujian normal university', 2),
#  ('guangdong polytechnic normal university', 2),
#  ('guangxi medical university', 2),
#  ('hainan normal university', 2),
#  ('harbin medical university', 2),
#  ('hebei normal university', 2),
#  ('heilongjiang university', 2),
#  ('huaihai institute of technology', 2),
#  ('inner mongolia agricultural university', 2),
#  ('jiangxi university of finance and economics', 2),
#  ('ningbo university of technology', 2),
#  ('northern jiaotong university', 2),
#  ('northwest a&f university', 2),
#  ('panzhihua university', 2),
#  ('shaanxi normal university', 2),
#  ('shanghai normal university', 2),
#  ('shanxi university', 2),
#  ('suzhou university', 2),
#  ('wuyi university', 2),
#  ('xiangtan university', 2),
#  ('yanbian university', 2),
#  ('university of west bohemia', 2),
#  ('hochschule darmstadt', 2),
#  ('technische universität chemnitz', 2),
#  ('universität der bundeswehr münchen', 2),
#  ('universität koblenz-landau', 2),
#  ('universität paderborn', 2),
#  ('universität passau', 2),
#  ('universität potsdam', 2),
#  ('universität rostock', 2),
#  ('it university of copenhagen', 2),
#  ('odense university', 2),
#  ('university of tartu', 2),
#  ('future university', 2),
#  ('sadat academy for management sciences', 2),
#  ('sohag university', 2),
#  ('universidad de almería', 2),
#  ('universidad de cantabria', 2),
#  ('universidad de salamanca', 2),
#  ('universidad de santiago de compostela', 2),
#  ('agroparistech', 2),
#  ('ecole centrale de nantes', 2),
#  ('ecole nationale supérieure des mines de paris', 2),
#  ('ecole normale supérieure de paris', 2),
#  ('ecole supérieure de physique et de chimie industrielles', 2),
#  ('institut national des sciences appliquées de rennes', 2),
#  ('institut national polytechnique de grenoble', 2),
#  ('université de haute-alsace', 2),
#  ('université de la rochelle', 2),
#  ('université de savoie', 2),
#  ('université du havre', 2),
#  ('anglia ruskin university', 2),
#  ('cranfield university', 2),
#  ('glasgow caledonian university', 2),
#  ('imperial college school of medicine', 2),
#  ('leeds metropolitan university', 2),
#  ('napier university', 2),
#  ('university of bedfordshire', 2),
#  ('university of brighton', 2),
#  ('university of chester', 2),
#  ('university of greenwich', 2),
#  ('university of hull', 2),
#  ('university of stirling', 2),
#  ('university of the west of england, bristol', 2),
#  ('university of wales, bangor', 2),
#  ('university of wolverhampton', 2),
#  ('agricultural university of athens', 2),
#  ('athens university of economics and business', 2),
#  ('harokopio university', 2),
#  ('university of central greece', 2),
#  ('chu hai college', 2),
#  ('university of osijek', 2),
#  ('pázmány péter catholic university', 2),
#  ('universitas indonesia', 2),
#  ('university of limerick', 2),
#  ('ariel university center of samaria', 2),
#  ('the interdisciplinary center herzliya', 2),
#  ('amity university', 2),
#  ('andhra university', 2),
#  ('banasthali university', 2),
#  ('bengal engineering college', 2),
#  ('dhirubhai ambani institute of information and communication technology', 2),
#  ('fakir mohan university', 2),
#  ...]

# %%
search_term = "carnegie mellon university"
country = ""

# %%
cursor.execute("select AffiliationID, Name from Affiliations where Name like %s", [f"%{search_term}%"])
all_matching_affiliations = cursor.fetchall()
print(len(all_matching_affiliations))
all_matching_affiliations
# Out:
# 127
# [(43, 'Carnegie Mellon University'),
#  (702, 'Robotics Institute, Carnegie Mellon University, Pittsburgh, PA'),
#  (773,
#   'Computer Science Department, Carnegie Mellon University, Pittsburgh, PA'),
#  (911, 'Department of Statistics, Carnegie Mellon University, Pittsburgh, PA'),
#  (2289, 'Software Engineering Institute, Carnegie Mellon University'),
#  (2986, 'Carnegie Mellon University, SGT'),
#  (4545,
#   'School of Computer Science, Carnegie Mellon University, Pittsburgh, PA'),
#  (4798,
#   'Computer Science Department, School of Computer Science, Carnegie Mellon University, Pittsburgh, PA'),
#  (4799,
#   'Human-Computer Interface Institute, School of Computer Science, Carnegie Mellon University, Pittsburgh, PA'),
#  (4852,
#   'CS Department and HCI Institute, Carnegie Mellon University, Pittsburgh, PA'),
#  (4878, 'Carnegie Mellon University, Pittsburgh, PA'),
#  (5234, 'Carnegie Mellon University Qatar'),
#  (5412,
#   'Department of Electrical and Computer Engineering, Carnegie Mellon University, Pittsburgh'),
#  (5413, 'Robotics Institute, Carnegie Mellon University, Pittsburgh'),
#  (5464, 'The Robotics Institute, Carnegie Mellon University, Pittsburgh, PA'),
#  (5481,
#   'School of Computer Science, Carnegie Mellon University, 5000 Forbes Avenue, Smith Hall, Pittsburgh'),
#  (5514,
#   'Department of Biological Sciences, Center for Automated Learning and Discovery, Carnegie Mellon University, Pittsburgh, PA'),
#  (5573,
#   'Robotics Institute, Department of Electrical and Computer Engineering, Carnegie Mellon University, Pittsburgh, PA'),
#  (5594,
#   'Language Technologies Institute, Carnegie Mellon University, Pittsburgh, PA'),
#  (6019,
#   'Department of Mathematical Sciences, Carnegie Mellon University, Pittsburgh, PA'),
#  (6020,
#   'Biomedical Engineering Department, Carnegie Mellon University, Pittsburgh, PA'),
#  (6031,
#   'Dept. of Electrical and Computer Engineering, Carnegie Mellon University, Pittsburgh'),
#  (6234,
#   'Department of Electrical and Computer Engineering, Carnegie Mellon University, Pittsburgh, PA'),
#  (6419,
#   'Department of Electrical and Engineering, Carnegie Mellon University, Pittsburgh, PA'),
#  (6877,
#   'Pittsburgh NMR Center for Biomedical Research, Carnegie Mellon University, Mellon Institute, Pittsburgh, PA'),
#  (6920, 'Informedia Project, Carnegie Mellon University, Pittsburgh, PA'),
#  (7149,
#   'Department of Computer Science, Carnegie Mellon University, Pittsburgh, PA'),
#  (7314,
#   'Electrical and Computer Engineering, Carnegie Mellon University, Pitsburg, PA'),
#  (7849, 'Carnegie Mellon University Africa'),
#  (8156, 'Machine Learning Department, Carnegie Mellon University, Pittsburgh'),
#  (8256,
#   'Department of Biomedical Engineering, Carnegie Mellon University, Pittsburgh, PA'),
#  (8393,
#   'Dept. of Electrical and Computer Engineering, Carnegie Mellon University, Pittsburgh, PA'),
#  (8472, 'Robotics Institute, Carnegie Mellon University'),
#  (8691, 'Carnegie Mellon University, Robotics Institute, Pittsburgh, PA'),
#  (8971,
#   'Department of Electrical and Computer Engineering, Carnegie Mellon University'),
#  (9025, 'Roboties Institute, Carnegie Mellon University'),
#  (9047,
#   'Center for Bioimage Informatics, Carnegie Mellon University, Pittsburgh, PA'),
#  (9183, 'School of Computer Science, Carnegie Mellon University'),
#  (9361, 'The Robotics Institute, Carnegie Mellon University'),
#  (9388, 'Computer Science Department, Carnegie Mellon University'),
#  (9744,
#   'Electrical & Computer Engineering, Carnegie Mellon University, Pittsburgh, PA'),
#  (10146,
#   'Medical Robotics Technology Center, Robotics Institute, Carnegie Mellon University, Pittsburgh, PA'),
#  (10284,
#   'Electrical and Computer Engineering Department, Carnegie Mellon University, Pittsburgh'),
#  (10696, 'Carnegie Mellon University, Pittsburgh'),
#  (10793,
#   'The Department of Electrical and Computer Engineering, Carnegie Mellon University, Pittsburgh, PA'),
#  (11139, 'Department of Mechanical Engineering, Carnegie Mellon University'),
#  (11140, 'Department of Biomedical Engineering, Carnegie Mellon University'),
#  (11218,
#   'National Resource for Biomedical Supercomputing, Pittsburgh Supercomputing Center, Carnegie Mellon University, 15213, Pittsburgh, Pennsylvania'),
#  (11260,
#   'School of Computer Science, Carnegie Mellon University, 15213, Pittsburgh, PA'),
#  (11714,
#   'Lane Center for Computational Biology and Machine Learning Department, School of Computer Science, Carnegie Mellon University, Pittsburgh, Pennsylvania'),
#  (11715,
#   'Computer Science Department, School of Computer Science, Carnegie Mellon University, Pittsburgh, Pennsylvania'),
#  (11969, 'Institute for Robotics, Carnegie Mellon University'),
#  (11984,
#   'Computer Science Dept., Carnegie Mellon University, 15213, Pittsburgh, PA'),
#  (12011,
#   'Department of Electrical & Computer Engineering, Carnegie Mellon University, 15213, Pittsburgh, PA'),
#  (12192,
#   'Electrical and Computer Engineering Department, Carnegie Mellon University, 15213, Pittsburgh'),
#  (12399,
#   'Carnegie Mellon University, 5000 Forbes Avenue, 15213, Pittsburgh, PA'),
#  (12850,
#   'School of Computer Science, Carnegie Mellon University, Pittsburgh, Pennsylvania 15213'),
#  (12871,
#   'Materials Science & Engineering Department, Carnegie Mellon University, 15213, Pittsburgh, PA'),
#  (13204,
#   'Robotics Institute, Carnegie Mellon University, 5000 Forbes Ave, 15213, Pittsburgh, PA'),
#  (13380,
#   'The Robotics Institute, Carnegie Mellon University, 15213, Pittsburgh, PA'),
#  (13496,
#   'Machine Learning Department, Carnegie Mellon University, PA 15213, Pittsburgh'),
#  (13946,
#   'Department of Electrical and Computer Engineering, Carnegie Mellon University, 15213, Pittsburgh'),
#  (14117, 'Carnegie Mellon University, 15213, Pittsburgh'),
#  (14381,
#   'Robotics Institute, Carnegie Mellon University, 5000 Forbes Avenue, 15213, Pittsburgh, PA'),
#  (14668,
#   'Center for the Neural Basis of Cognition, Carnegie Mellon University, 4400 Fifth Avenue, 15213, Pittsburgh, Pennsylvania'),
#  (15353, 'ECE Department, Carnegie Mellon University, Pittsburgh, PA'),
#  (15494, 'The Robotics Institute, Carnegie Mellon University, Pittsburgh'),
#  (15547,
#   'Electrical and Computer Engineering Department, Carnegie Mellon University, Pittsburgh, PA'),
#  (15719,
#   'Electrical and Computer Engineering, Carnegie Mellon University, Pittsburgh, PA'),
#  (16026, 'Carnegie Mellon University, 15213, Pittsburgh, PA'),
#  (16087,
#   'Department of Psychology, Carnegie Mellon University, 5000 Forbes Avenue, 15213, Pittsburgh, Pennsylvania'),
#  (16399,
#   'Joint Carnegie Mellon University-University of Pittsburgh PhD Program in Computational Biology, Pittsburgh, PA'),
#  (16412,
#   'Lane Center for Computational Biology, Carnegie Mellon University, Pittsburgh, Pennsylvania'),
#  (16413,
#   'Center for Bioimage Informatics, Carnegie Mellon University, Pittsburgh, Pennsylvania'),
#  (16477,
#   'Department of Electrical and Computer Engineering, Carnegie Mellon University, PA 15213, Pittsburgh'),
#  (16890,
#   'Department of Mathematical  Sciences, Carnegie Mellon University,  Pittsburgh, PA 15213, USA. e-mail: reha@andrew.cmu.edu.  Research supported in part by NSF through grant CCR-9875559.'),
#  (16986,
#   'Computer Science Department, Carnegie Mellon University, 15213, Pittsburgh, PA'),
#  (16989,
#   'Robotics Institute, Carnegie Mellon University, 5000 Forbes Avenue, PA 15213, Pittsburgh'),
#  (17099,
#   'Departments of Computer Science and Mathematics, Carnegie Mellon University, Pittsburgh, PA'),
#  (17633,
#   'Computer Science Department and The Robotics Institute, Carnegie Mellon University, Pittsburgh, PA'),
#  (18875,
#   'Department of Biomedical Engineering and the Center of Bioimage Informatics, Carnegie Mellon University, Pittsburgh, PA'),
#  (19070, 'Carnegie Mellon University Pittsburgh, PA'),
#  (19159,
#   'Scott Niekum is with the Robotics Institute, Carnegie Mellon University, Pittsburgh, PA'),
#  (20225,
#   'Interactive Systems Laboratories, School of Computer Science, Carnegie Mellon University'),
#  (20314,
#   'Robotics Institute/NREC, Carnegie Mellon University, Pittsburgh, PA'),
#  (20315, 'QRI8 lab, Carnegie Mellon University, Doha'),
#  (20371,
#   'Department of Biological Sciences, Carnegie Mellon University, Pittsburgh, PA'),
#  (20447,
#   'Robotics Institute, Carnegie Mellon University, Pittsburgh, Pennsylvania'),
#  (20552, 'ECE Department, Carnegie Mellon University, Pittsburgh'),
#  (20630, 'Carnegie Mellon University and Assistware Technology'),
#  (21163,
#   'Dept. of Biomedical Engineering and Center for Bioimage Informatics, Carnegie Mellon University, Pittsburgh'),
#  (21254,
#   'Machine Learning Department, School of Computer Science, Carnegie Mellon University, Pittsburgh, PA'),
#  (21411,
#   'Pittsburgh NMR Center for Biomedical Research, Department of Biological Sciences, Carnegie Mellon University, Pittsburgh, PA'),
#  (21865,
#   'Digital Mapping Laboratory, Department of Computer Science, Carnegie Mellon University, Pittsburgh, PA'),
#  (22034,
#   'Digital Mapping Laboratory, Computer Science Department, Carnegie Mellon University, Pittsburgh, PA'),
#  (22183, 'Carnegie Mellon University, Robotics Institute, Pittsburgh'),
#  (23511,
#   'Department of Biomedical Engineering, Carnegie Mellon University, Pittsburgh, PA 15213'),
#  (23737,
#   'Language Technologies Institute, Carnegie Mellon University, 5000 Forbes Avenue, Pittsburgh, PA 15213'),
#  (23948,
#   'Department of Electrical and Computer Engineering, Carnegie Mellon University, Pittsburgh, PA 15213'),
#  (24193,
#   'Department of Philosophy, Carnegie Mellon University, Pittsburgh, PA'),
#  (24570,
#   'Graduate School of Industrial Administration, Carnegie Mellon University, 5000 Forbes Ave., Pittsburgh, PA 15213'),
#  (25328,
#   'National Robotics Engineering Consortium, The Robotics Institute, Carnegie Mellon University, Pittsburgh, PA 15201'),
#  (25382,
#   'School of Computer Science, Carnegie Mellon University, Pittsburgh, Pennsylvania'),
#  (25426,
#   'Department of Mathematics, Carnegie Mellon University, Pittsburgh, Pennsylvania'),
#  (25671,
#   'The Robotics Institute, Carnegie Mellon University, Pittsburgh, PA 15213'),
#  (26404,
#   'School of Computer Science, Carnegie Mellon University, Pittsbuigh, PA 15213'),
#  (26492,
#   'Department of Applied Mathematics, Carnegie Mellon University, Pittsburgh, PA 15213, USA'),
#  (26602, 'School of Computer Science, Carnegie Mellon University, Pittsburgh'),
#  (26631, 'Disney Research Pittsburgh and Carnegie Mellon University'),
#  (26968, 'Carnegie Mellon University, Pittsburgh, Pennsylvania'),
#  (27051, 'Carnegie Mellon University, Urbana'),
#  (27321, 'GSIA, Carnegie Mellon University, Pittsburgh'),
#  (27374,
#   'Language Technologies Institute and Computer Science Department, Newell Simon Hall 3612D, Carnegie Mellon University, Pittsburgh'),
#  (27400,
#   'School of Computer Science, Carnegie Mellon University, Pittsburgh, PA and Just Research 4616 Henry Street, Pittsburgh'),
#  (27468,
#   'Department of Mathematics, Carnegie Mellon University, Pittsburgh, PA 15213'),
#  (27547, 'Carnegie Mellon University, Pittsburgh, USA'),
#  (27788,
#   'Department of Biomedical Engineering, Carnegie Mellon University, Pittsburgh, Pennsylvania, U.S.A.'),
#  (27811, 'Carnegie Mellon University, Pennsylvania'),
#  (27977,
#   'Department of Electrical and Computer Engineering, Carnegie Mellon University, Pittsburgh, Pennsylvania 15213'),
#  (28174,
#   'Department of Statistics, Carnegie Mellon University, Pittsburgh, Pennsylvania'),
#  (28221,
#   'Biomedical Engineering Program, Center for Light Microscope Imaging and Biotechnology, Carnegie Mellon University, Pittsburgh, Pennsylvania'),
#  (28595,
#   'The Robotics Institute, Carnegie Mellon University, 5000 Forbes Avenue, 15213, Pittsburgh'),
#  (28846, 'Department of Philosophy, Carnegie Mellon University, Pittsburgh'),
#  (30621,
#   'School of Computer Science, Carnegie Mellon University, 5000 Forbes Avenue, Pittsburgh, PA 15213'),
#  (31015,
#   'Center for Bioimage Informatics, Department of Biomedical Engineering, Carnegie Mellon University, Pittsburgh, 15213, USA'),
#  (31165,
#   'The authors are with the Center for Excellence in Optical Data Processing, Department of Electrical and Computer Engineering, Carnegie Mellon University, Pittsburgh, Pennsylvania 15213'),
#  (31257,
#   'School of Computer Science, Carnegie Mellon University, Pittsburgh, USA')]

# %%
replacement = {29849: ["Harvard University", "University of Western Ontario"]}

# %%
for key, value in replacement.items():
    cursor.execute("select * from affiliatedTo a where a.affiliatedTo = %s", [key])
    selected_authors = cursor.fetchall()
    print(selected_authors)
    for added_affiliation in value:
        cursor.execute("SELECT * FROM Affiliations a WHERE a.Name=%s", [added_affiliation])
        entry = cursor.fetchone()
        if not entry:
            cursor.execute("INSERT INTO Affiliations (Name) VALUES (%s)", [added_affiliation])
            lastrowid = cursor.lastrowid
        else:
            lastrowid = entry[0]
        for selected_author in selected_authors:
            try:
                cursor.execute("INSERT INTO affiliatedTo VALUES (%s,%s)", [selected_author[0],lastrowid])
            except mysql.connector.IntegrityError:
                continue
    cursor.execute("delete from affiliatedTo a where a.affiliatedTo = %s", [key])
    cursor.execute("delete from Affiliations a where a.AffiliationID = %s", [key])
cnx.commit()
# Out:
# [('144290222', 29849)]

# %%
grouped_affiliation_name = "Massachusetts Institute of Technology"
cursor.execute("SELECT * FROM Affiliations a WHERE a.Name=%s", [grouped_affiliation_name])
entry = cursor.fetchone()
if not entry:
    cursor.execute("INSERT INTO Affiliations (Name) VALUES (%s)", [grouped_affiliation_name])
    affiliation_id = cursor.lastrowid
else:
    affiliation_id = entry[0]
cnx.commit()
affiliation_id
# Out:
# 92

# %%
for affiliation in all_matching_affiliations:
    if affiliation[0] == affiliation_id:
        continue
    cursor.execute("select * from affiliatedTo a where a.affiliatedTo = %s", [affiliation[0]])
    selected_authors = cursor.fetchall()
    for selected_author in selected_authors:
        try:
            cursor.execute("INSERT INTO affiliatedTo VALUES (%s, %s)", [selected_author[0],affiliation_id])
        except mysql.connector.IntegrityError:
            continue
    cursor.execute("delete from affiliatedTo a where a.affiliatedTo = %s", [affiliation[0]])
    cursor.execute("delete from Affiliations a where a.AffiliationID = %s", [affiliation[0]])
cnx.commit()
